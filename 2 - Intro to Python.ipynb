# %% [markdown]
# <div>
#     <img style="float:right; width:210px" src="images/snext-logo.png"/>
#     <div style="float:left;"><h1>Introduction to Python for Data Science</h1></div>
# </div>

# %% [markdown]
# ---
# # Notebook 2: Introduction to Python
# Welcome to this beginner-friendly introduction to some programming basics in python, covering the tools and concepts you need to do data exploration and analysis with python.
#
# In this notebook, you'll take your first steps into programming by exploring core consepts such as variables, operators, control flow, data structures and external packages.
#
# This notebook is not a comprehensive programming manual. For more details see the [Python language reference](https://docs.python.org/3/reference/index.html).
# Take your time to read, run, and experiment with the code cells—learning happens by doing! I encourage you to ask questions and get curious:-) (Most importantly do not despair)
#
# ## Contents
# [0. Fundamentals: What is a Computer Program & Pseudocode](#chapter0)
# [1. Hello world!](#chapter1)
# [2. Comments and Variables](#chapter2)
# [3. Basic operators](#chapter3)
# [4. Control flow](#chapter4)
# [5. Data structures](#chapter5)
# [6. Working with packages](#chapter6)
# [7. Outlook](#chapter7)
#
# ---

# %% [markdown]
# # 0. Fundamentals: What is a Computer Program & Pseudocode<a id="chapter0"/>
#
# A **computer program** is like a detailed cooking recipe. It is a list of instructions written so that a computer can perform a sequence of tasks. Unlike humans, who can fill in gaps and infer missing steps, computers need every single instruction spelled out. For example, if a recipe simply says "walk to the oven" without specifying **how** to walk, a robot would get stuck. Similarly, if your program tells the computer to do something without providing enough detail, it will throw an error.
#
# Writing code is much easier and more successful when starting with **pseudocode**, which means writing out a solution or the steps of a program in deatiled everyday language before translating it directly into Python, writing out the steps in pseudocode mimics how a computer thinks, this process helps spot gaps in ogic before any actual coding begins. Especially for beginners, since one major hurdle is translating their idea of what a program should do, their conecptual understanding, into actual code that the computer can run, which is precise language syntax.
# Once the pseudocode is complete, each instruction can be more easily mapped onto lines of Python or any other programming language
# Before we dive into the code, let's warm up by running our first cell.

# %% [markdown]
# ## <span style="color:#FF5D02;">Assignment: Write your own pseudocode</span>
# Practice breaking down a process into step-by-step instructions using pseudocode before translating to Python code. Write a pseudocode for the following scenario in a markup cell: "Make a sandwich"

# %% [raw]
# One possible solution:
# BEGIN
#     1.Walk to the counter
#     2.Get a plate
#     3.Get break package
#     4.Unzip bread package
# ...
# END

# %% [markdown]
# # 1. Hello world!<a id="chapter1"/>
# Jupyter notebooks let you mix Markdown (for formatted text like this) and code cells. A Python interpreter, called the kernel, runs in the background. Whenever you execute a code cell (press Shift+Enter), its contents are sent to the kernel, which runs the code and displays the result below the cell. Markdown cells are not sent to the kernel; instead they render formatted text.
# Running code interactively is great for learning because you can see results immediately and iteratively improve your code. Let's try printing a message to the screen.

# %% [markdown]
# ## <span style="color:#FF5D02;">Assignment: Hello World!</span>
# Enter the python code ```print("Hello world!")``` in the following cell of type "code" and hit shift-enter to execute the cell.

# %% [markdown]
# In the cell below, write Python code that prints **any message** you like. Use the `print()` function. Run the cell by pressing **Shift+Enter**.

# %% [markdown]
# By right-clicking a cell and selecting "Clear output" you can remove that output again. By right-clicking a cell and selecting "Restart Kernel" this background python session is restarted.

# %% [markdown]
# ## 2. Comments and Variables <a id="chapter2"/>
#
# We're now going to explore some basic functionality. While reading along, please execute the code cells and always feel free to experiment :-)
#
# ### 2.1. Full line and inline comments
#
# Porgramming is all about **communication** both with the computer and other people who might read your code. When writing code, we often want to leave notes for ourselves or others. These notes are comments. In Python, any text after a # on a line is ignored by the interpreter. Use comments to describe what your code does — this makes your notebook easier to read and maintain.

# %%
# Use a hash sign at the beginning of a line for a full line comment

print ("Comments help to better understand your code")   # Example for an inline comment

# %% [markdown]
# ### 2.2 Working with simple variables
# Variables are names that refer to data stored in memory. In Python you don't need to declare a type ahead of time; the type is inferred from the value you assign. Variables can hold **numbers**, **strings** (text), **lists**, and more. Naming your variables meaningfully makes your code more readable. This is done via the `=`
# operator.
#
# > When working with texts, always put them in quotes so python knows that this is not a command or reference to another variable.
#
# Let's see some example of how you define variables and use their content:

# %%
x = 5     # just assign a value
y = 10

title = "Introduction to python"   # Important: don't forget the quotes around text data ("strings")

# let's use these variables

print (x)
print (y)
print (title)

print ("Values: ", x, y)   # print can output multiple variables at once, just separate them with commas
print ("x = ", x)

# %% [markdown]
# ## <span style="color:#FF5D02;">Assignment: Hello World with a variable</span>
# Redesign your "Hello World" program from above so that the text is first stored in a variable. You can pick any name for your variable.
# Next use the print function to output the contents of your newly created variable.

# %% [markdown]
# **Hints**
# (please try it yourself before looking)

# %%
# Solution
text = "Hello world"
print(text)

# %% [markdown]
# ---

# %% [markdown]
# To get the value of a variable, we don't have to write a print statement every time. As a shortcut, you can simply put the value in the last line of a cell:

# %%
x = 2
x

# %% [markdown]
# ## 3. Basic Operators & Built-in functions<a id="chapter3"/>
#
# ### 3.1. Basic Operators
# Operators let you combine values and produce new ones. In Python:
#
# - **Arithmetic operators**: `+` (addition), `-` (subtraction), `*` (multiplication), `/` (division), `**` (exponentiation).
# - **String concatenation**: `+` joins two strings into one.
# - **Comparison operators**: `>`, `<`, `==` (equals), `!=` (not equal), `>=`, `<=` compare values and return `True` or `False`.
# - **Assignment operator**: `=` assigns a value to a variable. Don't confuse it with `==` which tests equality.
#
# Let's see these operators in action.

# %%
x = 2
y = 3

mean = (x+y) / 2

print (mean)

# Assignment: Add a variable z and include it in the mean value calculation!
# Out:
# 2.5

# %%
# Example strings

s1 = "Steinbeis"
s2 = "School for Management"
s3 = "and Innovation"

print(s1 + " " + s2)

# Assignment: Alter the print statement so that the full name is printed!

# %%
# Comparing operators

a = 5.2
b = 10.8

print ("a < b? ", a < b)
print ("a == b? ", a == b)
print ("a != b? ", a != b)

# %% [markdown]
# ### 3.2. Built-in functions
# A function is a pre-written block of a code that that performs common tasks with data and variables in Python. An example of a built-in functions that we already used above is `print()`.
# Python provides many of those, `print`is for showing output on the screen, `type()` is to check what type of data you have, `len()`is to count items and so many more.
#
# To use (or “call”) a function, write its name, followed by parentheses. Inside the paranthesis there comes the argument, an argument is a value or object you provide to the function so it can complete its task. Different functions expect different arguments—for example:

# %%
#the function len can take a string as an argument and it counts how many characters are in that string
len("Pink Floyd")
#the function max takes a few numbers as arguments and gives you the maximum
max(1,2,3,4,7,12)

#Assignment: figure out what the function abs() does, experiment around with arguments

# %% [markdown]
# ## 4. Control flow <a id="chapter4"/>
# Programs need to make decisions and repeat actions. **Control flow** structures like `if` statements and loops let you control which instructions run, and how many times they run.
# ### 4.1. *IF* statements, indentation and bool operators
# An `if` statement runs a block of code only if its condition evaluates to `True`. With the ```else``` statement you can specify commands to be executed in case the condition of the ```if``` statement does not aply. Conditions can be combined using `and` and `or`.
# > Python relies on **indentation** to define blocks of code; a consistent indent (usually 4 spaces) is required after `if`, `for`, and `while` statements.

# %%
x = 5
y = 10

print(x < y)

# %%
if (x < y):
    print ("X is less than Y")
else:  # if the condition statment is not true
    print ("Y is larger than X")

# %%
x = 5  # if you like, change this value to validate the behavior of the following if statement

if (x == 5):
    print ("x equals 5")
    
print("Please note: this is not indented, thus not part of the if statment. This is why this text is always printed, no matter what value x holds.")

# %% [markdown]
# You can also link several conditions with the operators `and` and `or`:

# %%
if (x < 10) and (y < 100):
    print ("The numbers are not that big")

# %%
if (x < 10) or (y < 10):
    print ("One of the numbers is less than ten")

# %% [markdown]
# ## 4.2. Loops
# ### FOR
# A `for` loop allows you to execute one or more commands for each element of an enumeration. Experiment with the following examples and assignments until you have an intuitive understanding of what is happening in a FOR loop.
#
# Example:

# %%
for i in (1,2,3,4,5): #  For each of the values 1-5 go through the following code. The current number will be stored in the variable "i" during that pass.
    print ("For loop start...")
    print ("The value of i in this round is: ", i)
    print ("For loop end!")    
    print ("") # just an empty line

# %% [markdown]
# This will be helpful e.g. when "walking" though a dataset, checking things or making changes to "each customer", "each website vistor", "each machine operations cycle"...

# %% [markdown]
# ### WHILE
# The `while` loop executes one or more commands until the While condition is no longer met.
# Example:

# %%
x = 0
while x < 10:
    print ("Let's get started with another round in the while loop...")
    print ("In this round, x has the value of ", x)
    x = x + 1
    print ("End of the round")
    print ("")

# %% [markdown]
# ---
# ## <span style="color:#FF5D02;">Assignment: Loops and conditions</span>
# Create a program that ...
# - counts from 0 to 10
# - outputs a line of text for each number, stating the number and whether the value is less than five
# - for the line of number "5", skip showing the usual text, just the message "--- Phew, half time! ---"
#
# I know that's a lot - but try to solve it step-by-step, iteratively. Create a program that does the counting. Next, perhaps add the "half time" output, if you have an idea how that could work.
# If you need more help, expand the cells below to get one hint at a time... but please try first :-)

# %% [markdown]
# **Hints**

# %% [markdown]
# This output would be a valid solution:
# ```
# 0 (less than 5)
# 1 (less than 5)
# 2 (less than 5)
# 3 (less than 5)
# 4 (less than 5)
# --- Phew half time! ---
# 6
# 7
# 8
# 9
# 10
# ```

# %% [markdown]
# You need an iteration structure (for or while) and inside some IFs to determine what should happen each "round". Try to copy paste some code from above.

# %% [markdown]
# Instead of always printing the current number with `print(x)`, start with an `if (x<5): ...`.

# %% [markdown]
# Do the same for the other cases... `if (x == 5): ...` and `if (x>5): ...`

# %%
# One possible solution

for i in range(0,11):
    if (i < 5):
        print(i, "(less than 5)")

    if (i == 5):
        print(i, "--- Phew, half time! ---")
        
    if (i > 5):
        print(i)

# %% [markdown]
# ---

# %% [markdown]
# # 5. Data structures<a id="chapter5"/>
# To work with collections of data you need structures beyond single variables. **Lists** and **dictionaries** are the most common built‑in data structures in Python. For the full set of available structures please check the [documentation](https://docs.python.org/3/tutorial/datastructures.html#).
#
# ## 5.1. Lists
# A *list* is an ordered collection of items. Use square brackets `[]` to define a list. List elements are accessed by their index (the first element is index 0).
#
# > Important: The index of the first element of a list is 0.

# %%
x = ["Apples", "Oranges", "Bananas"]
print (x)

# %%
print (x[0])
print (x[1])

# %% [markdown]
# Indexing also works "backwards" - with negative index values. So the last element has the index -1.
# Before executing the next cell, think about what it should output!

# %%
x[-1]

# %% [markdown]
# `.append()` is used to add further values to a list.

# %%
x.append("Pears")
print(x)

# %% [markdown]
# Lists can also contain lists in turn - nested—lists of lists allow you to represent tabular data, like a table of people where each inner list holds one row.
#
#
# An example:

# %%
# Table: Surname, Firstname, Sex, Age, Height, Nationality
person1 = ["Nick"   , "Cave"   , "m" , 68, 1.92, "Australia"]
person2 = ["Stevie" , "Nicks" , "f" , 77, 1.72, "United States of America"]
person3= ["Lata", "Mangeshkar", "f", 92, 1.55, "India" ]
p = [person1, person2, person3]

p

# %% [markdown]
# To understand how to access individual data fields in nested lists, you need to take a closer look at Python's index system:

# %%
p[0]    # this returns the first element of list p - no surprise here
        # but this first element is no simple value, it is - again - a list

# %% [markdown]
# If I specify two index values, I can directly access all individual values:

# %%
print("First attribute of the first person: ", p[0][0] )
print("Second attribute of the first person: ", p[0][1] )
print("Third attribute of the second person: ", p[1][2] )
# ... :-)

# %% [markdown]
# <img src="https://www.practicaldatascience.org/_images/2.3.30-matrix_subsetting_0.png"
#      alt="Matrix subsetting illustration" width="500"/>
#
# *Figure: Matrix subsetting (row and column indexing) from PracticalDataScience.*
# Source: PracticalDataScience, _“Matrix subsetting”_, https://www.practicaldatascience.org/_images/2.3.30-matrix_subsetting_0.png

# %% [markdown]
# ## 5.2. Dictionaries

# %% [markdown]
# An unpleasant thing about lists is that there are no "column headers", in other words, the data fields have no names.
#
# The data structure "Dictionary" can be used for this purpose. A *dictionary* stores key–value pairs. Keys are unique names (usually strings) that map to values. This makes dictionaries ideal for representing structured data with named fields. Use curly braces `{}` to define a dictionary. When you have multiple records, a list of dictionaries acts like a table with named columns.  Our people example looks like this as a dictionary:

# %%
person1 = {
    "lastname":   "Cave", 
    "firstname":  "Nick",
    "gender":     "m",
    "age":        68,
    "height":     1.92
}

person2 = {
    "lastname":   "Nicks", 
    "firstname":  "Stevie",
    "gender":     "f",
    "age":        77,
    "height":     1.72
}

person3= {
    "lastname":   "Mangeshkar", 
    "firstname":  "Lata",
    "gender":     "f",
    "age":        92,
    "height":     1.55
}
# Same as above, we can put these two dictionaries in a list:

p = [person1, person2, person2]

# Finally, let's show the contents of p

p

# %% [markdown]
# You can now reference the fields of that data structure more comfortably:

# %%
print(p[0]["lastname"])
print(p[1]["age"])

# %% [markdown]
# ---
# ## <span style="color:#FF5D02;">Assignment: Data structures</span>
# Write a program that, starting from the last data structure "p", lists all names in the form "first-name last-name".

# %% [markdown]
# **Hints**

# %% [markdown]
# First try to show firstname lastname of the first record. Then use a loop to go through all the records

# %%
# Solution

for i in (0,1):
    # for each iteration, variable i contains the number of that iteration
    print(p[i]["firstname"], p[i]["lastname"])

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Working with packages <a id="kapitel6"/>

# %% [markdown]
# The Python language is modular - the core is limited to the most important commands and functions. A large part of the functionality is outsourced to so-called packages (also known as modules, libraries, ...). Python packages can be installed through package managers, which in the simplest case is the Python Package Installer `pip`. You can search for packages in the [Python Package Index PyPI](https://pypi.org).
#
# **Example**: the random number generator is contained in the package `random`. Using this package with the `import` command provides us with some new commands:

# %%
import random

# Should I stay or should I go?

options = ["stay", "go"]

random.choice (options) # Each time you execute this cell, one of the options will be picked randomly

# %% [markdown]
# Using the documentation [here](https://docs.python.org/3/library/random.html), we can figure out, that
# - random.randint(a, b) gives us a random integer number between a and b,
# - random.uniform(a, b) gives us a random floating point number between a and b
#
# ## Putting it all together
#
# To repeat all previous learnings and using the random package, we can now generate a list of random imaginary people.
# See if you can read below code and understand what it does!

# %%
# Let's generate some random people names for our list

import random

lastnames = ["Hughes", "Wakeman", "Venga", "Young", "Dobbson"]
firstnames_m = ["Matthew", "Conrad", "Thomas", "John", "Zak"]       # male first names
firstnames_f = ["Yasmin", "Melissa", "Sally", "Diane", "Chelsea"]   # female first names

genders = ["m", "f"]

height_f_min = 1.55   # minimal height of gender "female"
height_f_max = 1.75   # maximal height of gender "female"

age_min = 18
age_max = 95

# generate 10 random records

p = [] # start with an empty list

for i in range(0,10): # iterate though 0..9

    rand_lastname = random.choice(lastnames)    # pick one of the lastnames
    rand_gender = random.choice(genders)        # pick one of the genders
    rand_age = random.randint(age_min, age_max) # pick a random age between age_min and age_max
    rand_height = random.uniform(height_f_min, height_f_max) # pick a random floating point number between min and max

    # depending of the gender, pick a random name from one of the first name lists
    
    if (rand_gender == "m"):
        rand_firstname = random.choice(firstnames_m)
        rand_height = rand_height * 1.15  # males are 15% taller on average
        
    if (rand_gender == "f"):
        rand_firstname = random.choice(firstnames_f)
            
    p.append({
        "lastname":   rand_lastname, 
        "firstname":  rand_firstname,
        "gender":     rand_gender,
        "age":        rand_age,
        "height":     round(rand_height, 2)   # round the height to 2 decimal digits, before adding to the p list
        })

# %% [markdown]
# Now, let's have a look at the result :-)

# %%
p

# %% [markdown]
# ---
# ## <span style="color:#FF5D02;">Assignment: Random Pets</span>
# It is important to get a somehow intuitive understanding of the control flow and the list/dictionary data structures.
# To practice, try to come up with your own program, that generates a dataset of 10 random pets. Each record of a pet should include:
# - Species (dog, cat, hamster)
# - A name that is typical for the species
# - A weight (min/max) that is typical for each kind
# - Optional, if you like: Faviorite pet food for the kind (meat, fish, muesli pellets, carrots, corn, ...)

# %% [markdown]
# **Hints**

# %% [markdown]
# If you get stuck, try to build a dictionary with one pet and just one or two first. Then expand to the full attribute set and the loop to generate multiple records.

# %% [markdown]
# # Outlook
# Congratulations on completing this introduction! You've learned about running code, using variables, operators, control structures, data structures, and importing packages.
# These are the building blocks for all your future Python programs. Many packages in the python package index are quite powerful. The whole Jupyter Lab environment is a package for example.
#
# ### What's Next?
# To showcase to what degree packages can simplify your code, let's use `pandas` (package for data analysis and manipulation) to quickly import and display some data from the web:

# %% [markdown]
# The pandas package contains a function to extract tabular data from web pages - a process that usually involves many steps: Contacting web servers, receiving HTML data, finding the table, interpreting HTML table code, and finally extracting the data.
#
# The following code reads world country data from Wikipedia ([link](http://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations))).

# %%
import pandas # import package

link = "http://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)"
data = pandas.read_html(link, storage_options={"User-Agent": "Mozilla/5.0"})

data[0] # show first table (index 0 in the list of retrieved tables)
# Out:
#                   Country or territory  Population (1 July 2022)  \
# 0                                World                8021407192
# 1                                India                1425423212
# 2                             China[a]                1425179569
# 3                        United States                 341534046
# 4                            Indonesia                 278830529
# ..                                 ...                       ...
# 233        Montserrat (United Kingdom)                      4453
# 234  Falkland Islands (United Kingdom)                      3490
# 235              Tokelau (New Zealand)                      2290
# 236                 Niue (New Zealand)                      1821
# 237                    Vatican City[w]                       505
#
#      Population (1 July 2023) Change (%) UN continental region[1]  \
# 0                  8091734930     +0.88%                        –
# 1                  1438069596     +0.89%                     Asia
# 2                  1422584933     −0.18%                     Asia
# 3                   343477335     +0.57%                 Americas
# 4                   281190067     +0.85%                     Asia
# ..                        ...        ...                      ...
# 233                      4420     −0.74%                 Americas
# 234                      3477     −0.37%                 Americas
# 235                      2397     +4.67%                  Oceania
# 236                      1817     −0.22%                  Oceania
# 237                       496     −1.78%                   Europe
#
#     UN statistical subregion[1]
# 0                             –
# 1                 Southern Asia
# 2                  Eastern Asia
# 3              Northern America
# 4            South-eastern Asia
# ..                          ...
# 233                   Caribbean
# 234               South America
# 235                   Polynesia
# 236                   Polynesia
# 237             Southern Europe
#
# [238 rows x 6 columns]

# %% [markdown]
# You may now continue to work on the third notebook for this task "3 - Pandas", where we get an intro to **data analysis with pandas**: reading, cleaning, and manipulating tabular data using the `pandas` library. A pandas `DataFrame` acts like a spreadsheet in code.
